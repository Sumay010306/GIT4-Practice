# %% [markdown]
# # LINEAR REGRESSION PRACTICE - 2
#
# Without tutorial

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
folder_name = r"C:/Sumay"
name = "wage2.csv"
print(os.path.join(folder_name,name))
# Out:
# C:/Sumay\wage2.csv

# %%
data = pd.read_csv('C:/Sumay/wage2.csv')
data
# Out:
#      MonthlyEarnings  AveWeeklyHours   IQ  Knowledge  YearsEdu  \
# 0                769              40   93         35        12
# 1                808              50  119         41        18
# 2                825              40  108         46        14
# 3                650              40   96         32        12
# 4                562              40   74         27        11
# ..               ...             ...  ...        ...       ...
# 930              520              40   79         28        16
# 931             1202              40  102         32        13
# 932              538              45   77         22        12
# 933              873              44  109         25        12
# 934             1000              40  107         32        12
#
#      YearsExperience  Tenure  Age  Married  Black  South  Urban  NumSiblings  \
# 0                 11       2   31        1      0      0      1            1
# ...

# %%
sns.stripplot(data, x='YearsEdu', y='MonthlyEarnings', jitter=True)
# Out:
# <Axes: xlabel='YearsEdu', ylabel='MonthlyEarnings'>

# %%
#Loss function
def loss_function(m,b,points):
    total_error=0
    for i in range(len(points)):
        x=points.iloc[i].YearsEdu
        y=points.iloc[i].MonthlyEarnings
        total_error+=(y-(m*x+b))**2
    total_error/float(len(points))

# %%
#Gradient Descent
def gradient_descent(m_now, b_now, points, L):
    m_gradient=0
    b_gradient=0
    n=len(points)
    for i in range(n):
        x=points.iloc[i].YearsEdu
        y=points.iloc[i].MonthlyEarnings
        m_gradient += -(2/n)*x*(y-(m_now*x+b_now))
        b_gradient += -(2/n)*(y-(m_now*x+b_now))
    m=m_now - m_gradient*L
    b=b_now - b_gradient*L
    return m,b

# %%
m=0
b=0
L=0.00001
epochs=1000
for i in range(epochs):
    m,b=gradient_descent(m,b,data,L)
print(m,b)
plt.scatter(data.YearsEdu, data.MonthlyEarnings)
plt.plot(list(range(8,20)),[m*x+b for x in range(8,20)], color='red')
plt.show()
# Out:
# 68.81421775938524 5.051145870412457
